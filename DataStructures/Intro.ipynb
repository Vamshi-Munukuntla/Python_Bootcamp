# %% [markdown]
# ## What is a Data Sturcture?

# %% [markdown]
# ![image.png](attachment:efc1085c-87a6-416e-906e-055291435ebb.png)

# %% [markdown]
# Data Structures are different ways of organizing data on your computer, that can be used effectively.

# %% [markdown]
# ![image.png](attachment:d11847ea-3429-4c60-b655-9aa5ab2c3c9a.png)

# %% [markdown]
# ![image.png](attachment:d29cfe46-1f31-43c6-860e-a7c27ac8335a.png)

# %% [markdown]
# ![image.png](attachment:030d41f8-84d9-402e-973e-9927419e0877.png)

# %% [markdown]
# ## What is an algorithm?

# %% [markdown]
# ![image.png](attachment:22de0519-8114-4550-ba81-5e5d287b549f.png)

# %% [markdown]
# Algorithm - Set of instruction to perform a Task.

# %% [markdown]
# ### Steps to perform a flooring

# %% [markdown]
# ![image.png](attachment:8db3709c-d075-449e-b2b7-b594c019fdaa.png)

# %% [markdown]
# ### Algorithms in our daily life

# %% [markdown]
# Going to Office

# %% [markdown]
# ![image.png](attachment:05a67c60-9e21-4966-9054-8fc54d3bc604.png)

# %% [markdown]
# Buying a Coffee

# %% [markdown]
# ![image.png](attachment:40393324-e4ea-44c6-b534-80f5adeb09f7.png)

# %% [markdown]
# ### Algos in CS

# %% [markdown]
# ![image.png](attachment:1459b12f-0b08-4ed0-9c02-618396777cab.png)

# %% [markdown]
# ## Types of Data Structures

# %% [markdown]
# ![image.png](attachment:937ededb-d049-4fd7-b4ef-a7f47aa67071.png)

# %% [markdown]
# ![image.png](attachment:57ea0c83-ae08-40a9-946a-b922bd9bd06e.png)
