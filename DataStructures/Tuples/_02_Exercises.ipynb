# %% [markdown]
# ![image.png](attachment:6511efcc-b188-46a1-8f31-439828b61529.png)

# %% [markdown]
# ## Sum Tuple Elements using Unpack

# %%
# Write a Python program to unpack tuple in several variables
# and print out sum of these variables, the output must be as shown below.

# Example

# my_tuple = (10, 40, 80, 90)

# Output

# 10+40+80+90=220

# %%
my_tuple = (10, 40, 80, 90)

# %%
a,b,c,d = my_tuple

# %%
print(f'{a}+{b}+{c}+{d}={a+b+c+d}')
# Out:
# 10+40+80+90=220

# %%
total = 0
for i in my_tuple:
    total += i
print(total)
# Out:
# 220

# %% [markdown]
# ## Even Index with Enumerate

# %%
# Implement a function which takes as a parameter a tuple and return a new tuple but only have even index elements from original tuple.

# Hint : Use enumerate() function

# Example

# my_tuple = ("a", "b", "c", "d", "e", "f", "g")
# even_index_items(my_tuple)
# Output

# ('a', 'c', 'e', 'g')

# %%
my_tuple = ("a", "b", "c", "d", "e", "f", "g")

# %%
def even_index_items(p_tuple):
    new_list = list()
    for index,value in enumerate(p_tuple):
        if index %2 == 0:
            new_list.append(value)
    return tuple(new_list)

# %%
even_index_items(my_tuple)
# Out:
# ('a', 'c', 'e', 'g')

# %% [markdown]
# ## Find most frequent item

# %%
# Implement a function which takes a tuple as a parameter and 
# returns another tuple with two elements. 
# First element is the most frequent item and
# the second element of number of repetition.

# Hint: Use count() method

# Example

# my_tuple = ("a","b","c","d","e","a","c","e","b","e","c","a","f","e","r")
# most_frequent(my_tuple)
# Output

# ('e', 4)

# %%
my_tuple = ("a","b","c","d","e","a","c","e","b","e","c","a","f","e","r",'e')

# %%
def most_frequent(my_tuple):
    max = 0
    for index, value in enumerate(my_tuple):
        if my_tuple.count(value) > max:
            max = my_tuple.count(value)
            print(max,index,value)
    return (my_tuple[max],max)

# %%
def most_frequent(p_tuple):
    max_count = 0
    item = p_tuple[0]
    for value in p_tuple:
        current_item_count = p_tuple.count(value)
        if current_item_count > max_count:
            max_count = current_item_count
            item = value
    return (item, max_count)

# %%
most_frequent(my_tuple)
# Out:
# ('e', 4)

# %% [markdown]
# ## Nested Tuple Indexing

# %%
# Using nested indexing print the following items from clubs tuple.

# The name of first player from Arsenal

# The year that Manchester United FC founded.

# Squad number of Dembele

# The tuple representing the 2nd player in Real Madrid CF

# Output

# Lacazette
# 1878
# 7
# (9, 'Benzema')

# %%
clubs = (("FC Barcelona", "Spain", 1899,
            [
                (3, "Pique"),
                (5, "Busquets"),
                (7, "Dembele"),
            ]
         ),
         ("Real Madrid CF", "Spain", 1902,
            [
                (7, "Hazard"),
                (9, "Benzema"),
                (10, "Modric"),
            ]
         ),
         ("Manchester United FC", "England", 1878,
            [
                (6, "Pogba"),
                (7, "Ronaldo"),
                (14, "Lingard"),
            ]
         ),
         ("Arsenal FC", "England", 1886,
            [
                (7, "Lacazette"),
                (14, "Aubameyang"),
                (16, "Holding"),
            ]
         ),
         )

# %%
# Name of the first player from arsenal
print('Club Name :', clubs[3][0])
print('First Player Name: ',clubs[3][3][0][1])
# Out:
# Club Name : Arsenal FC
# First Player Name:  Lacazette

# %%
# The year that Manchester United FC founded.
print('Club Name :', clubs[2][0])
print('Year Founded: ',clubs[2][2])
# Out:
# Club Name : Manchester United FC
# Year Founded:  1878

# %%
# Squad number of Dembele
print('Club Name :', clubs[0][0])
print('Player Name :',clubs[0][3][2][1])
print('Squad Number :',clubs[0][3][2][0])
# Out:
# Club Name : FC Barcelona
# Player Name : Dembele
# Squad Number : 7

# %%
# The tuple representing the 2nd player in Read Madrid CF
print('Club Name :', clubs[1][0])
print('Player Name :',clubs[1][3][1][1])
print('Squad Number :',clubs[1][3][1][0])
# Out:
# Club Name : Real Madrid CF
# Player Name : Benzema
# Squad Number : 9

# %% [markdown]
# ## Convert Tuple to Dictionary

# %%
# Implement a function which takes a list of tuples as a parameter and 
# convert it to a dictionary and return the dictionary.

# Example

# tuple_list = [("one", 1), ("two", 2), ("three", 3), ("four", 4)]
# convert_to_dict(tuple_list)
# Output

# {'one': 1, 'two': 2, 'three': 3, 'four': 4}

# %%
tuple_list = [("one", 1), ("two", 2), ("three", 3), ("four", 4)]

# %%
def convert_to_dict(tup_list):
    result_dict = {}
    for key,value in tup_list:
        result_dict.setdefault(key, value)
    return result_dict

# %%
convert_to_dict(tuple_list)
# Out:
# {'one': 1, 'two': 2, 'three': 3, 'four': 4}

# %% [markdown]
# ## Comparing Tuples

# %%
# Implement a function which takes a string (sentence) as a parameter
# and returns a tuple in which the words from the given sentenced
# are ordered based on their length.

# Example

# order_words("Python is my favorite programming language")

# Output

# ('is', 'my', 'Python', 'favorite', 'language', 'programming')

# %%
def order_words(p_text):
    words = p_text.split()
    nested_list = list()
    for word in words:
        nested_list.append((len(word),word))
    nested_list.sort()
    result_list = []
    for length, word in nested_list:
        result_list.append(word)
    return tuple(result_list)

# %%
text = "Python is my favorite programming language"
order_words(text)
# Out:
# ('is', 'my', 'Python', 'favorite', 'language', 'programming')
