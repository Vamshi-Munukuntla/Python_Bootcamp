# %% [markdown]
# ![image.png](attachment:0bae8988-d043-4fcc-8723-b5876ebefe13.png)

# %% [markdown]
# ![image.png](attachment:1b60f9bc-f047-45d8-8cd2-ac2562989707.png)

# %% [markdown]
# ### Generate Dictionary

# %%
n = 5
def generate_dictionary(p_n):
    gen_dict = {}
    for i in range(1,p_n+1):
        gen_dict[i] = i**2
    return gen_dict

generate_dictionary(n)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %% [markdown]
# ### Multiply Dictionary Items

# %%
my_dict = {"One" : 1, "Two" : 2, "Three" : 3, "Four" : 4}

# %%
def multiply_values(p_dict):
    mul = 1
    for key in p_dict:
        mul = mul* p_dict[key]
    return mul

# %%
multiply_values(my_dict)
# Out:
# 24

# %% [markdown]
# ### Student Grades

# %%
student_scores = {
  "John": 90,
  "Edy": 68,
  "Marry": 88, 
  "Ewan": 79,
  "Park": 62,
}

# %%
def convert_grade(p_dict):
    student_grade = {}
    for i in student_scores:
        if student_scores[i] < 50:
            student_grade[i] = 'Fail'
        elif student_scores[i] < 64:
            student_grade[i] = 'Acceptable'
        elif student_scores[i] < 84:
            student_grade[i] = 'Good'
        else:
            student_grade[i] = 'Outstanding'
    return student_grade

# %%
convert_grade(student_scores)
# Out:
# {'John': 'Outstanding',
#  'Edy': 'Good',
#  'Marry': 'Outstanding',
#  'Ewan': 'Good',
#  'Park': 'Acceptable'}

# %% [markdown]
# ### Group Value Types

# %%
custom_list = [10, "one", "two", "ten", 20, 30, "five", 40, "nine", 50]

# %%
def group_types(custom_list):
    for i in custom_list:
        datatype = type(i)
        new_dict = {}.fromkeys(custom_list,datatype)
    return new_dict

# %%
group_types(custom_list)
# Out:
# {10: int,
#  'one': int,
#  'two': int,
#  'ten': int,
#  20: int,
#  30: int,
#  'five': int,
#  40: int,
#  'nine': int,
#  50: int}

# %%
def group_types(p_list):
    output_dict = {}.fromkeys(p_list,'test')
    for key in output_dict.keys():
        if isinstance(key, int):
            output_dict[key] = 'Integer'
        else:
            output_dict[key] = 'String'
    return (output_dict)

# %%
group_types(custom_list)
# Out:
# {10: 'Integer',
#  'one': 'String',
#  'two': 'String',
#  'ten': 'String',
#  20: 'Integer',
#  30: 'Integer',
#  'five': 'String',
#  40: 'Integer',
#  'nine': 'String',
#  50: 'Integer'}

# %% [markdown]
# ### Length of Dictionary Values

# %%
# <!-- Length of Dictionary Values -->
# Implement a function which takes a dictionary as a parameter and returns new dictionary.  
# In new dictionary the keys remain same but values will be another nested dictionary. 
# Nested dictionary's keys will be values from original dictionary and values will be length of values from original dictionary. 
# <!-- (I know it is confusing, see example below you will understand it :) ) -->

# Example

# names_dict = {
#     1 : "Elshad",
#     2 : "Renad",
#     3 : "Johanna",
#     4 : "Appmillers"
# }
# value_length(names_dict)
# Output

# {
#     1: {'Elshad': 6}, 
#     2: {'Renad': 5}, 
#     3: {'Johanna': 7}, 
#     4: {'Appmillers': 10}
# }

# %%
names_dict = {
    1 : "Elshad",
    2 : "Renad",
    3 : "Johanna",
    4 : "Appmillers"
}

# %%
def value_length(names_dict):
    output_dict = {}.fromkeys(names_dict,None)
    for key, value in names_dict.items():
        output_dict[key] = {value:len(value)}
    return output_dict

# %%
value_length(names_dict)
# Out:
# {1: {'Elshad': 6}, 2: {'Renad': 5}, 3: {'Johanna': 7}, 4: {'Appmillers': 10}}

# %%
my_dict = {
    1:'one',
    2:'two',
    3:'three'
}

# %%
value_length(my_dict)
# Out:
# {1: {'one': 3}, 2: {'two': 3}, 3: {'three': 5}}

# %% [markdown]
# ### Concatenate Three Dictionaries

# %%
# Implement a function which takes three dictionaries as parameters 
# and concatenate them into one new dictionary without updating the current ones 
# and returns new dictionary with all elements of these three dictionaries in it.

# Hint : use update() method of dictionary.

# Example

# dict1={1: "one", 2: "two"}
# dict2={3: "three", 4: "four"}
# dict3={5: "five", 6: "six"}
 
# concatenate(dict1,dict2,dict3)
# Output

# {
#     1: 'one', 
#     2: 'two', 
#     3: 'three', 
#     4: 'four', 
#     5: 'five', 
#     6: 'six'
# }
#

# %%
dict1={1: "one", 2: "two"}
dict2={3: "three", 4: "four"}
dict3={5: "five", 6: "six"}

# %%
new_dict = {}
new_dict.update(dict1)
print(new_dict)
# Out:
# {1: 'one', 2: 'two'}

# %%
def concatenate(d1, d2, d3):
    new_dict = dict()
    for d in [d1, d2, d3]:
        new_dict.update(d)
    return new_dict

# %%
concatenate(dict1, dict2, dict3)
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four', 5: 'five', 6: 'six'}

# %% [markdown]
# ### Remove Empty Items

# %%
# Remove Empty Items
# Implement a function which takes as a parameter dictionary and
# removes empty items from it and return new dictionary.
# If there is not any empty item in the dictionary it will return itself.

# Example

# custom_dict = {
#     "name" : "Elshad",
#     "age" : 28,
#     "city" : None
# }
# remove_empty_items(custom_dict)
# Output

# {'name': 'Elshad', 'age': 28}

# %%
custom_dict = {
    "name" : "Elshad",
    "age" : 28,
    "city" : None
}

# %%
def remove_empty_items(custom_dict):
    new_dict = {}
    for key, value in custom_dict.items():
        if value != None:
            new_dict[key] = value
    return new_dict

# %%
remove_empty_items(custom_dict)
# Out:
# {'name': 'Elshad', 'age': 28}

# %%
def remove_empty(custom_dict):
    for key, value in list(custom_dict.items()):
        print(key, value)
        if value is None:
            custom_dict.pop(key)
    return custom_dict

# %%
remove_empty(custom_dict)
# Out:
# name Elshad
# age 28
# city None
# {'name': 'Elshad', 'age': 28}

# %% [markdown]
# ### Merge Two Dictionary

# %%
# Implement a function which takes as parameter two dictionaries and merge these two dictionaries using Dictionary methods into third dictionary.

# Note : loop is not allowed

# Example

# dict1 = {'One': 2, 'Two': 2, 'Three': 3}
# dict2 = {'Three': 3, 'Four': 4, 'Five': 5}
# merge_dict(dict1, dict2)
# Output

# {'One': 2, 'Two': 2, 'Three': 3, 'Four': 4, 'Five': 5}

# %%
def merge_dict(dict1, dict2):
    output_dict = dict1.copy()
    output_dict.update(dict2)
    return output_dict

# %%
dict1 = {'One': 2, 'Two': 2, 'Three': 3}
dict2 = {'Three': 3, 'Four': 4, 'Five': 5}
merge_dict(dict1, dict2)
# Out:
# {'One': 2, 'Two': 2, 'Three': 3, 'Four': 4, 'Five': 5}

# %% [markdown]
# ### Custom Deep Copy for List Values

# %%
# Implement custom deep copy method for a dictionary where the values are lists.

# Example

# original_dict = {
#     "names" : ["Elshad", "John", "Edy"],
#     "numbers" : [1,2,3,4,5]
# }
 
# copied_dict = deep_copy(original_dict)
# copied_dict["names"].append("Jack")
# copied_dict["numbers"].append(6)
 
# print(original_dict)
# print(copied_dict)
# Output

# {
#     'names': ['Elshad', 'John', 'Edy'], 
#     'numbers': [1, 2, 3, 4, 5]
# }
 
# {
#     'names': ['Elshad', 'John', 'Edy', 'Jack'], 
#     'numbers': [1, 2, 3, 4, 5, 6]
# }

# %%
original_dict = {
    "names" : ["Elshad", "John", "Edy"],
    "numbers" : [1,2,3,4,5]
}

# %%
def deep_copy(p_dict):
    
    new_dict = {}
    for key, value in p_dict.items():
        new_value  = value.copy()
        new_dict[key] = new_value
    return new_dict

# %%
copied_dict = deep_copy(original_dict)

# %%
copied_dict['numbers'].append(6)

# %%
print(copied_dict)
# Out:
# {'names': ['Elshad', 'John', 'Edy'], 'numbers': [1, 2, 3, 4, 5, 6]}

# %%
print(original_dict)
# Out:
# {'names': ['Elshad', 'John', 'Edy'], 'numbers': [1, 2, 3, 4, 5]}
