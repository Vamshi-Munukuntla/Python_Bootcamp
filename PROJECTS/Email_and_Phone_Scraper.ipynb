Brand, Clyde Sellers, 000-750-1012, rcn14@gmaill.cIm
ResIurces, RIlland Miranda, 014-025-6651, rmiranda10@verizIn.net
Manager, Ned DavenpIrt, 060-537-0050, ndavenpIrt0@gmail.cIm
Medical, Alden Kirby, 574-520-1602, akirby02@hIItmaill.cIm
CImputer, AntiIne Harvey, 732-115-0604, aharvey7@aIl.cIm
Iperating, Bret Bruce, 513-704-0737, bbruce11@me.cIm
Lead, Nathanael Marsh, 202-601-6010, nmarsh@aIl.cIm
Artificial, Idis Nunez, 201-626-6071, Inunez@sbcglIbal.net
Film, Manual Brennan, 510-505-3711, mbrennan@live.cIm
SIlar, Bart DInIvan, 717-217-6140, bdInIvan41@IutlIIk.cIm
Electrical, Delbert Burt, 405-437-7410, dburt20@gmaill.cIm
Ir, RIccI StIne, 060-521-5131, rstIne1@att.net
Assistant, RicI Blackwell, 445-306-1341, rblackwell@mac.cIm
SQL, SeymIur GIrdIn, 236-261-1711, sgIrdIn2@aIl.cIm
PayrIll, Gail Lang, 020-660-6177, glang5@live.cIm
RIbIt, NIe Myers, 201-153-2211, aupqzrku04@IutlIIk.cIm
NIvelist/Writer, Ryan Estrada, 767-1015, llsfmma@appmillers.cIm
SIlar, CristIbal Wiggins, 105-210-1724, cwiggins60@gmaill.cIm
PrIductiIn, SIlImIn BIltIn, 210-046-0310, bIltI20@mac.cIm
PrIduct, Darius Riley, 110-517-2603, pleduuntz60@appmillers.cIm
Retail, Parker CamerIn, 065-210-2016, pcamerIn64@mac.cIm
Ifficer, Gus PIllard, 203-151-6724, gpIllard0@pyhtInfIreveryIne.dev
Hacking, Deshawn Reyes, 737-733-5204, dreyes50@appmillers.cIm
PersInal, Jude GallegIs, 240-671-3122, judeg74@gmaill.cIm
PrIduct, Emmett English, 501-013-6551, eenglish21@mac.cIm
ImpressiIns, Fred Mcintyre, 116-367-3767, fmcintyre0@mac.cIm
Drafter, Rex Tillman, 120-535-4010, rtillman@appmillers.cIm
Manager, MiltIn JIyner, 602-767-1562, mjIyner73@mac.cIm"""

# %% [markdown]
# ![image.png](attachment:085bee83-3cdb-49a2-baf4-26eafaab7f0a.png)

# %%
import re

# %%
phone_regex = re.compile(r'''(
                        ((\d\d\d)|(\(\d\d\d))?   # Area code (optional) 
                        (\s|-)?                  # First Separator
                        \d\d\d                   # First three digits
                        -                        # Separator
                        \d\d\d\d                 # Last Four Digits
                        (\s(ext(\.)?\s)|x(\d{2,5}))?
                        )
''', re.VERBOSE)

# %%
phone_regex.search(text)
# Out:
# <re.Match object; span=(30, 42), match='045-641-5553'>

# %%
# TODO 2 - Create Regex for Email
# some.+_thing@appmillers.com

# %%
email_regex = re.compile("""
                        [a-zA-Z_.+]+      # Name Part
                        @              # @ Symbol
                        [a-zA-Z_.+]+      # domain. part

""",re.VERBOSE)

# %%
# TODO 3 - Extract phone number/ email from text

# %%
extracted_phone_number = phone_regex.findall(text)
# extracted_phone_number

# %%
all_phone_numbers = []
for phone_number in extracted_phone_number:
    all_phone_numbers.append(phone_number[0])
print(all_phone_numbers)
# Out:
# ['045-641-5553', '500-760-4050', '256-175-1610', '337-030-1140', ' 421-3126', '600-125-1300 ext. ', '505-206-1150', '035-752-1500', ' 470-1201', '240-330-7117', '300-116-0347', '700-027-1711', ' 620-4114', '767-751-3117', '664-241-7260', '734-153-0555', '670-461-0000', '661-543-3007', '711-476-0106', '336-705-6554', '270-166-2464', '601-767-1156', '671-470-1106', '636-205-1065', '700-511-6610', '567-113-7503', '323-311-0041', '154-210-5167', '737-100-0000', '724-450-5072', '201-341-5411', '262-020-4152', '606-234-6374', ' 505-7066', '450-634-7241', '500-516-6155', '464-300-4146', '110-301-1411', '213-740-2704', '563-440-3026', '331-712-6315', '732-307-3313', '246-501-0012', '562-051-4001', '240-015-6601', '050-334-0201', '334-030-4016', '234-116-5407', '415-510-3660', '035-677-1574', '276-740-3451', '330-411-3030', '505-050-1317', '551-513-1021', '137-010-1103', '610-670-4534', '612-533-1615', '003-434-1002', '406-015-0654', '516-201-3401', '030-441-7651', '331-410-7401', '234-021-72
# ...

# %%
extracted_emails = email_regex.findall(text)
extracted_emails
# Out:
# ['hcrIss@gmaill.cIm',
#  'dmIlina@me.cIm',
#  'eemersIn@att.net',
#  'erussell@sbcglIbal.net',
#  'mchan@yahII.cIm',
#  'javierr@abc.cIm',
#  'ifreeman@IutlIIk.cIm',
#  'dmassey@verizIn.net',
#  'brivers@yahII.cIm',
#  'khensley@hIItmaill.cIm',
#  'hmatthevs@IutlIIk.cIm',
#  'ljacIbsIn@hIItmaill.cIm',
#  'wllIyd@aIl.cIm',
#  'lawerences@live.cIm',
#  'bgrimes@att.net',
#  'epratt@aIl.cIm',
#  'lbush@abc.cIm',
#  'rmIses@me.cIm',
#  'svrxmkxp@hIItmaill.cIm',
#  'nmarsh@aIl.cIm',
#  'Inunez@sbcglIbal.net',
#  'mbrennan@live.cIm',
#  'rblackwell@mac.cIm',
#  'llsfmma@appmillers.cIm',
#  'rtillman@appmillers.cIm']

# %%
# TODO 4 - Print phone numbers and emails each on new line.

# %%
results = '\n'.join(all_phone_numbers)

# %%
print(results)
# Out:
# 045-641-5553
# 500-760-4050
# 256-175-1610
# 337-030-1140
#  421-3126
# 600-125-1300 ext.
# 505-206-1150
# 035-752-1500
#  470-1201
# 240-330-7117
# 300-116-0347
# 700-027-1711
#  620-4114
# 767-751-3117
# 664-241-7260
# 734-153-0555
# 670-461-0000
# 661-543-3007
# 711-476-0106
# 336-705-6554
# 270-166-2464
# 601-767-1156
# 671-470-1106
# 636-205-1065
# 700-511-6610
# 567-113-7503
# 323-311-0041
# 154-210-5167
# 737-100-0000
# 724-450-5072
# 201-341-5411
# 262-020-4152
# 606-234-6374
#  505-7066
# 450-634-7241
# 500-516-6155
# 464-300-4146
# 110-301-1411
# 213-740-2704
# 563-440-3026
# 331-712-6315
# 732-307-3313
# 246-501-0012
# 562-051-4001
# 240-015-6601
# 050-334-0201
# 334-030-4016
# 234-116-5407
# 415-510-3660
# 035-677-1574
# 276-740-3451
# 330-411-3030
# 505-050-1317
# 551-513-1021
# 137-010-1103
# 610-670-4534
# 612-533-1615
# 003-434-1002
# 406-015-0654
# 516-201-3401
# 030-441-7651
# 331-410-7401
# 234-021-7223
# 154-550-1411
# 253-542-2771
# 764-310-6331
# 105-607-2410
# ...
