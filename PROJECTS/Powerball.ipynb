# %% [markdown]
# ![image.png](attachment:c5511a0c-6e43-48ee-8e2a-ec999467ee40.png)

# %% [markdown]
# ## Step 1

# %% [markdown]
# #### Ask the player to enter first 5 numbers between 1 and 69

# %%
# To do list

# TODO 1 - Check that the player entered 5 things

# TODO 2 - Convert the strings into integers

# TODO 3 - Check that the numbers are between 1 and 69

# TODO 4 - Check that the numbers are unique

# %%
# TODO 1 - Check that the player entered 5 things
while True:
    print('Enter 5 different numbers from 1 to 69, with spaces in between each number.')
    print('For Example: 5 17 23 42 59')
    response = input(">  ")

    numbers = response.split()
    if len(numbers) != 5:
        print('Please enter 5 numbers, separated by spaces.')
        continue

# TODO 2 - Convert the strings into integers
    try:
        for i in range(5):
            numbers[i] = int(numbers[i])
    except ValueError:
        print()
        print('Please enter numbers, like 1, 10, or 35')
        continue
        
# TODO 3 - Check that the numbers are between 1 and 69  
    for item in numbers:
        if not(1<=item <= 69):
            print("The numbers must be between 1 and 69")
            continue

# TODO 4 - Check that the numbers are unique
    if len(set(numbers)) != 5:
        print('You must enter 5 different numbers')
        continue
    break
# Out:
# Enter 5 different numbers from 1 to 69, with spaces in between each number.
# For Example: 5 17 23 42 59
# >   5 17 23 42 59

# %% [markdown]
# ## Step 2

# %% [markdown]
# #### Ask the player to select the powerball between 1 to 26

# %%
# To do list

# TODO 1 - Convert the strings into integers

# TODO 2 - Check that the number is between 1 and 26

# %%
# TODO 1 - Convert the strings into integers
while True:
    print("Enter the powerball number from 1 to 26.")
    response = input('> ')
    try:
        powerball = int(response)
    except ValueError:
        print('Please enter a number, like 25')
        continue
        
# TODO 2 - Check that the number is between 1 and 26
    if not (1 <= powerball <= 26):
        print('The powerball number must be between 1 and 26')
        continue
    break
# Out:
# Enter the powerball number from 1 to 26.
# >  41
# The powerball number must be between 1 and 26
# Enter the powerball number from 1 to 26.
# >  12

# %% [markdown]
# ## Step 3

# %% [markdown]
# #### Enter the number of times you want to play

# %%
# TODO 1 - Convert the strings into integers

# TODO 2 - Check that the number is between 1 and 1000000

# %%
while True:
    print('How many times do you want to play? (Max: 1000000)')
    response = input('>')
    
# TODO 1 - Convert the strings into integers
    try:
        numPlays = int(response)
    except ValueError:
        print('Please enter a number, like 25')
        continue
        
# TODO 2 - Check that the number is between 1 and 1000000
    if not (1 <= numPlays <= 1000000 ):
        print("You can play between 1 and 1000000 times only.")
        continue
    break
# Out:
# How many times do you want to play? (Max: 1000000)
# > 1
# It costs $2 to play 1 times, but don't worry.
# I'm sure you'll win it all back.
# Please Enter to start...

# %% [markdown]
# ## Step 4

# %% [markdown]
# #### Run the Simulation

# %%
import random

# %%
price = "$" + str(2 * numPlays)
print(f"It costs {price} to play {numPlays} times, buit dont worry.")
print("I'm sure you will win it all back.")
input('Press Enter to start...')

possibleNumbers = list(range(1,70))

for i in range(numPlays):

    # TODO 1 - Come up with lottery numbers
    random.shuffle(possibleNumbers)
    winningNumbers = possibleNumbers[:5]
    winningPowerball = random.randint(1, 26)

    # TODO 2 - Display winning Numbers
    print("The winning numbers are: ", end="")
    allWinningNumbers  = ""
    for num in winningNumbers:
        allWinningNumbers += str(num) + " "
    allWinningNumbers += 'and ' + str(winningPowerball)
    print(allWinningNumbers, end="")

    # TODO 3 - Check for winner
    if set(numbers) == set(winningNumbers) and powerball == winningPowerball:
        print()
        print('You have won the powerball lottery! Congratulations.')
    else:
        print('.  You lost.')

print(f'You have wasted {price}')
print('Thanks for playing')
# Out:
# It costs $4 to play 2 times, buit dont worry.
# I'm sure you will win it all back.
# Press Enter to start...
# The winning numbers are: 46 14 53 36 9 and 23.  You lost.

# %% [markdown]
# ## Complete Code

# %%
import random
# Step 1 - Ask the player to enter first 5 numbers between 1 and 69

# TODO 1 - Check that the player entered 5 things
while True:
    print('Enter 5 different numbers from 1 to 69, with spaces in between each number.')
    print('For Example: 5 17 23 42 59')
    response = input(">  ")

    numbers = response.split()
    if len(numbers) != 5:
        print('Please enter 5 numbers, separated by spaces.')
        continue

# TODO 2 - Convert the strings into integers
    try:
        for i in range(5):
            numbers[i] = int(numbers[i])
    except ValueError:
        print()
        print('Please enter numbers, like 1, 10, or 35')
        continue
        
# TODO 3 - Check that the numbers are between 1 and 69  
    between_1_69 = True
    for item in numbers:
        if not(1<=item <= 69):
            print("The numbers must be between 1 and 69")
            between_1_69 = False
            break
    if not between_1_69:
        continue   

# TODO 4 - Check that the numbers are unique
    if len(set(numbers)) != 5:
        print('You must enter 5 different numbers')
        continue
    break
    
    
# Step 2 - Ask the player to select the powerball between 1 to 26
    
# TODO 1 - Convert the strings into integers
while True:
    print("Enter the powerball number from 1 to 26.")
    try:
        response = int(input('> '))
    except ValueError:
        print('Please enter a number, like 25')
        continue
    
        
# TODO 2 - Check that the number is between 1 and 26
    if not (1 <= response <= 26):
        print('Please enter a number between 1 and 26')
        continue
    break

    
# Step 3 - Enter the number of times you want to play
while True:
    print('How many times do you want to play? (Max: 1000000)')
    response = input('>')
    
# TODO 1 - Convert the strings into integers
    try:
        numPlays = int(response)
    except ValueError:
        print('Please enter a number, like 25')
        continue
        
# TODO 2 - Check that the number is between 1 and 1000000
    if not (1 <= numPlays <= 1000000 ):
        print("You can play between 1 and 1000000 times only.")
        continue

    print(f"It costs ${2*numPlays} to play {numPlays} times, but don't worry.")
    print("I'm sure you'll win it all back. ")
    print('Please Enter to start...')
    break  
    
    
# Step 4 - Run the simulation

price = "$" + str(2 * numPlays)
print(f"It costs {price} to play {numPlays} times, buit dont worry.")
print("I'm sure you will win it all back.")
input('Press Enter to start...')

possibleNumbers = list(range(1,70))

for i in range(numPlays):

    # TODO 1 - Come up with lottery numbers
    random.shuffle(possibleNumbers)
    winningNumbers = possibleNumbers[:5]
    winningPowerball = random.randint(1, 26)

    # TODO 2 - Display winning Numbers
    print("The winning numbers are: ", end="")
    allWinningNumbers  = ""
    for num in winningNumbers:
        allWinningNumbers += str(num) + " "
    allWinningNumbers += 'and ' + str(winningPowerball)
    print(allWinningNumbers, end="")

    # TODO 3 - Check for winner
    if set(numbers) == set(winningNumbers) and powerball == winningPowerball:
        print()
        print('You have won the powerball lottery! Congratulations.')
        break
    else:
        print('.  You lost.')

print(f'You have wasted {price}')
print('Thanks for playing')
# Out:
# Enter 5 different numbers from 1 to 69, with spaces in between each number.
# For Example: 5 17 23 42 59
# >   90 10 41 52 53
# The numbers must be between 1 and 69
# Enter 5 different numbers from 1 to 69, with spaces in between each number.
# For Example: 5 17 23 42 59
# >   90 10 41 52 53
# The numbers must be between 1 and 69
# Enter 5 different numbers from 1 to 69, with spaces in between each number.
# For Example: 5 17 23 42 59
# >   9 10 41 52 53
# Enter the powerball number from 1 to 26.
# >  5
# How many times do you want to play? (Max: 1000000)
# > 5
# It costs $10 to play 5 times, but don't worry.
# I'm sure you'll win it all back.
# Please Enter to start...
# It costs $10 to play 5 times, buit dont worry.
# I'm sure you will win it all back.
# Press Enter to start... 5
# The winning numbers are: 17 4 12 14 2 and 17.  You lost.
# The winning numbers are: 23 31 4 10 32 and 21.  You lost.
# The winning numbers are: 18 14 64 65 52 and 25.  You lost.
# The winning numbers are: 6 60 3 61 58 and 24.  You lost.
# The winning numbers are: 27 63 2 32 69 and 12.  You lost.
# You have wasted $10
# Thanks for playing
