# %% [markdown]
# # HANGMAN

# %% [markdown]
# ![image.png](attachment:202a636f-60f8-4da3-8e30-8db0cae230aa.png)

# %% [markdown]
# ![image.png](attachment:8bd444c6-4df3-490e-9879-f010f0d6612f.png)

# %% [markdown]
# #### TODO 1

# %%
import random
word_list = ['UDEMY','APPMILLERS','PYTHON']
secret_word = random.choice(word_list)
length_word = len(secret_word)
print(secret_word)
# Out:
# PYTHON

# %% [markdown]
# #### TODO 2

# %%
blanks = []
for _ in range(length_word):
    blanks.append('_')

# %%
print(blanks)
# Out:
# ['_', '_', '_', '_', '_', '_']

# %% [markdown]
# #### TODO 3

# %%
user_input = input('Guess a letter: ').upper()
print(user_input)
# Out:
# Guess a letter:  h
# H

# %%
# import random
# word_list = ['UDEMY','APPMILLERS','PYTHON']
# secret_word = random.choice(word_list)
# length_word = len(secret_word)
# print(secret_word)

# blanks = []
# for _ in range(length_word):
#     blanks.append('_')
    
# user_input = input('Guess a letter: ').upper()
# print(user_input)

# %% [markdown]
# ![image.png](attachment:5f169b87-ad75-44ad-ac92-3ad47bb18c08.png)

# %% [markdown]
# #### TODO 1

# %%
import random
word_list = ['UDEMY','APPMILLERS','PYTHON']
secret_word = random.choice(word_list)
length_word = len(secret_word)
print(secret_word)

blanks = []
for _ in range(length_word):
    blanks.append('_')
# Out:
# UDEMY

# %%
guess = input('Guess a letter: ').upper()
guessed_letters = []
if guess in guessed_letters:
    print('You have already guessed this letter.')
else:
    guessed_letters.append(guess)

for position in range(length_word):
    letter = secret_word[position]
    if guess == letter:
        blanks[position] = letter
print(blanks)
# Out:
# Guess a letter:  j
# ['_', '_', '_', '_', '_', 'L', 'L', '_', '_', '_']

# %% [markdown]
# ![image.png](attachment:e99be650-acdb-48b3-8b1d-4c1a41751b8a.png)

# %%
# Out:
# PYTHON

# %%
guessed_letters = []
end_game = False
while not end_game:
    guess = input('Guess a letter: ').upper()
    if guess in guessed_letters:
        print('You have already guessed this letter.')
        continue
    else:
        guessed_letters.append(guess)
    print(guessed_letters)

    for position in range(length_word):
        letter = secret_word[position]
        if guess == letter:
            blanks[position] = letter
    print(blanks)
    if "_" not in blanks:
        end_game = True
# Out:
# Guess a letter:  l
# ['L']
# ['_', '_', '_', '_', '_', 'L', 'L', '_', '_', '_']
# Guess a letter:  a
# ['L', 'A']
# ['A', '_', '_', '_', '_', 'L', 'L', '_', '_', '_']
# Guess a letter:  m
# ['L', 'A', 'M']
# ['A', '_', '_', 'M', '_', 'L', 'L', '_', '_', '_']
# Guess a letter:  p
# ['L', 'A', 'M', 'P']
# ['A', 'P', 'P', 'M', '_', 'L', 'L', '_', '_', '_']
# Guess a letter:  i
# ['L', 'A', 'M', 'P', 'I']
# ['A', 'P', 'P', 'M', 'I', 'L', 'L', '_', '_', '_']
# Guess a letter:  r
# ['L', 'A', 'M', 'P', 'I', 'R']
# ['A', 'P', 'P', 'M', 'I', 'L', 'L', '_', 'R', '_']
# Guess a letter:  s
# ['L', 'A', 'M', 'P', 'I', 'R', 'S']
# ['A', 'P', 'P', 'M', 'I', 'L', 'L', '_', 'R', 'S']
# Guess a letter:  e
# ['L', 'A', 'M', 'P', 'I', 'R', 'S', 'E']
# ['A', 'P', 'P', 'M', 'I', 'L', 'L', 'E', 'R', 'S']

# %% [markdown]
# ![image.png](attachment:a604bd7f-3ab2-4c6d-9c2d-0672a4cd1dbc.png)

# %%
import random
word_list = ['UDEMY','APPMILLERS','PYTHON']
secret_word = random.choice(word_list)
length_word = len(secret_word)
print(secret_word)

blanks = []
for _ in range(length_word):
    blanks.append('_')

guessed_letters = []
lives = 6
end_game = False
while not end_game:
    guess = input('Guess a letter: ').upper()
    if guess in guessed_letters:
        print('You have already guessed this letter.')
        continue
    else:
        guessed_letters.append(guess)
    print(guessed_letters)

    for position in range(length_word):
        letter = secret_word[position]
        if guess == letter:
            blanks[position] = letter
            
    if guess not in secret_word:
        lives -= 1
    if lives == 0:
        end_game = True
        print('You Lose!')
        print('Actual Word: ',secret_word)
    print(" ".join(blanks))
    print(blanks)
    if "_" not in blanks:
        end_game = True
        print("You Win.")
# Out:
# PYTHON
# Guess a letter:  p
# ['P']
# ['P', '_', '_', '_', '_', '_']
# Guess a letter:  n
# ['P', 'N']
# ['P', '_', '_', '_', '_', 'N']
# Guess a letter:  s
# ['P', 'N', 'S']
# ['P', '_', '_', '_', '_', 'N']
# Guess a letter:  d
# ['P', 'N', 'S', 'D']
# ['P', '_', '_', '_', '_', 'N']
# Guess a letter:  l
# ['P', 'N', 'S', 'D', 'L']
# ['P', '_', '_', '_', '_', 'N']
# Guess a letter:  m
# ['P', 'N', 'S', 'D', 'L', 'M']
# ['P', '_', '_', '_', '_', 'N']
# Guess a letter:  z
# ['P', 'N', 'S', 'D', 'L', 'M', 'Z']
# ['P', '_', '_', '_', '_', 'N']
# Guess a letter:  b
# ['P', 'N', 'S', 'D', 'L', 'M', 'Z', 'B']
# You Lose!
# Actual Word PYTHON
# ['P', '_', '_', '_', '_', 'N']
